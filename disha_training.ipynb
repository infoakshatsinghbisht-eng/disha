# %% [markdown]
# # 🚀 Disha Multimodal Foundation Model — Kaggle Training Pipeline
# Train VQ-VAE and Multimodal Transformer on 30 GB RAM + GPU.

# %%
# Step 1: Clone Disha Repository & Install Dependencies
# !git clone https://github.com/infoakshatsinghbisht-eng/disha.git
# %cd disha
# !pip install -r requirements.txt

# %%
# Step 2: Verify GPU Accelerator
import torch
print('CUDA Available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU Device:', torch.cuda.get_device_name(0))
    print('Device Count:', torch.cuda.device_count())

# %%
# Step 3: Run Master Training Pipeline
# !python train_2b_master.py --train_samples 1000 --vq_epochs 10 --llm_epochs 10 --batch_size 8

# %%
# Step 4: Test Inference & View Output
# !python generate.py --prompt "a glowing celestial golden sun with radiant solar flares on deep cosmic void" --checkpoint checkpoints/multimodal_llm.pt --output test_eval.png
from PIL import Image
display(Image.open('test_eval.png'))
